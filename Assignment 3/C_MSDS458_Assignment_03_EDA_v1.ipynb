# %% [markdown]
# <a href="https://colab.research.google.com/github/alawrence30/Deep-Learning/blob/main/C_MSDS458_Assignment_03_EDA_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## Experiments C: LSTM
#
# Try several experiments by tweaking
#
# (i) architecture
#
# (ii) Bidirectional/unidirectional & other hyper parameters, including regularization

# %% [markdown]
# ## Functions and Packages

# %%
import datetime
from packaging import version
from collections import Counter
import numpy as np
import pandas as pd
import time
import string
import re

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers

import nltk
from nltk.corpus import stopwords

from tensorflow.keras.layers import Bidirectional
from keras.layers import LSTM
from keras.layers.core import Dense
from keras.layers.core import Activation

# %% [markdown]
# ### Verify TensorFlow version and Keras version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.9.2

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.9.0

# %% [markdown]
# ### Stopword Function

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %% [markdown]
# ## Mount Google Drive to Colab Environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# ## Load **Data**

# %%
# register  ag_news_subset so that tfds.load doesn't generate a checksum (mismatch) error
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums --datasets=ag_news_subset

dataset,info=\
tfds.load('ag_news_subset', with_info=True,  split=['train[:95%]','train[95%:]', 'test'],batch_size = 32
          , as_supervised=True)

train_ds, val_ds, test_ds = dataset
text_only_train_ds = train_ds.map(lambda x, y: x)
# Out:
# W1105 20:16:21.625852 140130614327168 download_and_prepare.py:43] ***`tfds build` should be used instead of `download_and_prepare`.***
# INFO[build.py]: Loading dataset ag_news_subset from imports: tensorflow_datasets.text.ag_news_subset
# 2022-11-05 20:16:21.715702: W tensorflow/core/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# INFO[dataset_info.py]: Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: ag_news_subset/1.0.0
# INFO[dataset_info.py]: Load dataset info from /tmp/tmp_izos_0mtfds
# INFO[dataset_info.py]: Field info.splits from disk and from code do not match. Keeping the one from code.
# INFO[dataset_info.py]: Field info.supervised_keys from disk and from code do not match. Keeping the one from code.
# INFO[dataset_info.py]: Field info.module_name from disk and from code do not match. Keeping the one from code.
# INFO[build.py]: download_and_prepare for dataset ag_news_subset/1.0.0...
# INFO[dataset_builder.py]: Generating dataset ag_news_subset (/root/tensorflow_datasets/ag_news_subset/1.0.0)
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
#
#
# INFO[download_manager.py]: Downloading https://drive.google.com/uc?export=download&id=0Bz8a_Dbh9QhbUDNpeUdjb0wxRms into /root/tensorflow_datasets/downloads/ucexport_download_id_0Bz8a_Dbh9QhbUDNpeUdjb0wxj4g1umFAV8OV-uDwxSJR0LdxO_k1jxMuFWwAfNX9jos.tmp.b3429c2be37f44b285058a7c888bc36b...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:   0% 0/11 [00:11<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:   9% 1/11 [00:11<01:58, 11.84s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  18% 2/11 [00:11<01:46, 11.84s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  27% 3/11 [00:11<01:34, 11.84s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  36% 4/11 [00:11<01:22, 11.84s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  45% 5/11 [00:11<01:11, 11.84s/ MiB]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  55% 6/11 [00:11<00:07,  1.47s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  64% 7/11 [00:11<00:05,  1.47s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  73% 8/11 [00:11<00:04,  1.47s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  82% 9/11 [00:11<00:02,  1.47s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  91% 10/11 [00:11<00:01,  1.47s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.47s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:11<00:00, 11.99s/ url]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.47s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:11<00:00, 11.99s/ url]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.47s/ MiB]
#
# Extraction completed...:   0% 0/1 [00:11<?, ? file/s]
#
# Dl Completed...: 100% 1/1 [00:12<00:00, 11.99s/ url]
# Dl Size...: 100% 11/11 [00:12<00:00,  1.47s/ MiB]
#
# Extraction completed...: 100% 1/1 [00:12<00:00, 12.32s/ file]
# Dl Size...: 100% 11/11 [00:12<00:00,  1.12s/ MiB]
# Dl Completed...: 100% 1/1 [00:12<00:00, 12.32s/ url]
# Generating splits...:   0% 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0% 0/120000 [00:00<?, ? examples/s]
# Generating train examples...:   1% 931/120000 [00:00<00:12, 9302.87 examples/s]
# Generating train examples...:   2% 1873/120000 [00:00<00:12, 9370.79 examples/s]
# Generating train examples...:   2% 2821/120000 [00:00<00:12, 9417.69 examples/s]
# Generating train examples...:   3% 3763/120000 [00:00<00:12, 9323.44 examples/s]
# Generating train examples...:   4% 4717/120000 [00:00<00:12, 9400.72 examples/s]
# Generating train examples...:   5% 5675/120000 [00:00<00:12, 9458.91 examples/s]
# Generating train examples...:   6% 6629/120000 [00:00<00:11, 9482.38 examples/s]
# Generating train examples...:   6% 7578/120000 [00:00<00:11, 9473.08 examples/s]
# Generating train examples...:   7% 8540/120000 [00:00<00:11, 9517.41 examples/s]
# Generating train examples...:   8% 9492/120000 [00:01<00:11, 9508.36 examples/s]
# Generating train examples...:   9% 10443/120000 [00:01<00:11, 9435.18 examples/s]
# Generating train examples...:  10% 11407/120000 [00:01<00:11, 9493.90 examples/s]
# Generating train examples...:  10% 12357/120000 [00:01<00:11, 9455.32 examples/s]
# Generating train examples...:  11% 13303/120000 [00:01<00:11, 9429.19 examples/s]
# Generating train examples...:  12% 14262/120000 [00:01<00:11, 9476.01 examples/s]
# Generating train examples...:  13% 15217/120000 [00:01<00:11, 9495.56 examples/s]
# Generating train examples...:  13% 16167/120000 [00:01<00:10, 9492.23 examples/s]
# Generating train examples...:  14% 17117/120000 [00:01<00:11, 9221.75 examples/s]
# Generating train examples...:  15% 18069/120000 [00:01<00:10, 9307.80 examples/s]
# Generating train examples...:  16% 19012/120000 [00:02<00:10, 9341.48 examples/s]
# Generating train examples...:  17% 19971/120000 [00:02<00:10, 9413.75 examples/s]
# Generating train examples...:  17% 20927/120000 [00:02<00:10, 9456.16 examples/s]
# Generating train examples...:  18% 21874/120000 [00:02<00:10, 9429.39 examples/s]
# Generating train examples...:  19% 22829/120000 [00:02<00:10, 9464.92 examples/s]
# Generating train examples...:  20% 23776/120000 [00:02<00:10, 9463.28 examples/s]
# Generating train examples...:  21% 24727/120000 [00:02<00:10, 9476.06 examples/s]
# Generating train examples...:  21% 25685/120000 [00:02<00:09, 9504.30 examples/s]
# Generating train examples...:  22% 26636/120000 [00:02<00:09, 9485.97 examples/s]
# Generating train examples...:  23% 27589/120000 [00:02<00:09, 9496.33 examples/s]
# Generating train examples...:  24% 28546/120000 [00:03<00:09, 9516.03 examples/s]
# Generating train examples...:  25% 29498/120000 [00:03<00:09, 9492.62 examples/s]
# Generating train examples...:  25% 30457/120000 [00:03<00:09, 9519.67 examples/s]
# Generating train examples...:  26% 31410/120000 [00:03<00:09, 9507.28 examples/s]
# Generating train examples...:  27% 32361/120000 [00:03<00:09, 9503.05 examples/s]
# Generating train examples...:  28% 33319/120000 [00:03<00:09, 9524.70 examples/s]
# Generating train examples...:  29% 34279/120000 [00:03<00:08, 9546.29 examples/s]
# Generating train examples...:  29% 35234/120000 [00:03<00:08, 9535.73 examples/s]
# Generating train examples...:  30% 36188/120000 [00:03<00:09, 9109.82 examples/s]
# Generating train examples...:  31% 37140/120000 [00:03<00:08, 9227.11 examples/s]
# Generating train examples...:  32% 38089/120000 [00:04<00:08, 9303.78 examples/s]
# Generating train examples...:  33% 39047/120000 [00:04<00:08, 9382.48 examples/s]
# Generating train examples...:  33% 40003/120000 [00:04<00:08, 9434.73 examples/s]
# Generating train examples...:  34% 40953/120000 [00:04<00:08, 9451.97 examples/s]
# Generating train examples...:  35% 41900/120000 [00:04<00:08, 9449.22 examples/s]
# Generating train examples...:  36% 42848/120000 [00:04<00:08, 9456.27 examples/s]
# Generating train examples...:  37% 43803/120000 [00:04<00:08, 9483.04 examples/s]
# Generating train examples...:  37% 44752/120000 [00:04<00:07, 9442.54 examples/s]
# Generating train examples...:  38% 45698/120000 [00:04<00:07, 9447.20 examples/s]
# Generating train examples...:  39% 46654/120000 [00:04<00:07, 9479.58 examples/s]
# Generating train examples...:  40% 47614/120000 [00:05<00:07, 9515.03 examples/s]
# Generating train examples...:  40% 48571/120000 [00:05<00:07, 9530.54 examples/s]
# Generating train examples...:  41% 49525/120000 [00:05<00:07, 9480.85 examples/s]
# Generating train examples...:  42% 50477/120000 [00:05<00:07, 9492.28 examples/s]
# Generating train examples...:  43% 51427/120000 [00:05<00:07, 9487.69 examples/s]
# Generating train examples...:  44% 52381/120000 [00:05<00:07, 9502.64 examples/s]
# Generating train examples...:  44% 53340/120000 [00:05<00:06, 9526.26 examples/s]
# Generating train examples...:  45% 54295/120000 [00:05<00:06, 9530.73 examples/s]
# Generating train examples...:  46% 55249/120000 [00:05<00:06, 9443.27 examples/s]
# Generating train examples...:  47% 56209/120000 [00:05<00:06, 9488.84 examples/s]
# Generating train examples...:  48% 57167/120000 [00:06<00:06, 9515.86 examples/s]
# Generating train examples...:  48% 58121/120000 [00:06<00:06, 9521.06 examples/s]
# Generating train examples...:  49% 59078/120000 [00:06<00:06, 9533.83 examples/s]
# Generating train examples...:  50% 60032/120000 [00:06<00:06, 9527.30 examples/s]
# Generating train examples...:  51% 60985/120000 [00:06<00:06, 9517.13 examples/s]
# Generating train examples...:  52% 61944/120000 [00:06<00:06, 9536.64 examples/s]
# Generating train examples...:  52% 62898/120000 [00:06<00:05, 9531.78 examples/s]
# Generating train examples...:  53% 63852/120000 [00:06<00:05, 9475.27 examples/s]
# Generating train examples...:  54% 64807/120000 [00:06<00:05, 9495.97 examples/s]
# Generating train examples...:  55% 65760/120000 [00:06<00:05, 9503.33 examples/s]
# Generating train examples...:  56% 66715/120000 [00:07<00:05, 9516.67 examples/s]
# Generating train examples...:  56% 67672/120000 [00:07<00:05, 9531.69 examples/s]
# Generating train examples...:  57% 68632/120000 [00:07<00:05, 9550.21 examples/s]
# Generating train examples...:  58% 69588/120000 [00:07<00:05, 9528.33 examples/s]
# Generating train examples...:  59% 70546/120000 [00:07<00:05, 9540.53 examples/s]
# Generating train examples...:  60% 71505/120000 [00:07<00:05, 9552.57 examples/s]
# Generating train examples...:  60% 72461/120000 [00:07<00:04, 9525.92 examples/s]
# Generating train examples...:  61% 73414/120000 [00:07<00:04, 9436.83 examples/s]
# Generating train examples...:  62% 74358/120000 [00:07<00:04, 9418.32 examples/s]
# Generating train examples...:  63% 75302/120000 [00:07<00:04, 9422.57 examples/s]
# Generating train examples...:  64% 76249/120000 [00:08<00:04, 9434.48 examples/s]
# Generating train examples...:  64% 77193/120000 [00:08<00:04, 9422.83 examples/s]
# Generating train examples...:  65% 78136/120000 [00:08<00:04, 9398.48 examples/s]
# Generating train examples...:  66% 79088/120000 [00:08<00:04, 9433.20 examples/s]
# Generating train examples...:  67% 80040/120000 [00:08<00:04, 9457.28 examples/s]
# Generating train examples...:  67% 80986/120000 [00:08<00:04, 9449.50 examples/s]
# Generating train examples...:  68% 81947/120000 [00:08<00:04, 9495.97 examples/s]
# Generating train examples...:  69% 82904/120000 [00:08<00:03, 9517.72 examples/s]
# Generating train examples...:  70% 83856/120000 [00:08<00:03, 9498.04 examples/s]
# Generating train examples...:  71% 84807/120000 [00:08<00:03, 9498.88 examples/s]
# Generating train examples...:  71% 85757/120000 [00:09<00:03, 9495.62 examples/s]
# Generating train examples...:  72% 86707/120000 [00:09<00:03, 9457.33 examples/s]
# Generating train examples...:  73% 87653/120000 [00:09<00:03, 9444.33 examples/s]
# Generating train examples...:  74% 88615/120000 [00:09<00:03, 9495.64 examples/s]
# Generating train examples...:  75% 89565/120000 [00:09<00:03, 9483.92 examples/s]
# Generating train examples...:  75% 90514/120000 [00:09<00:03, 9484.89 examples/s]
# Generating train examples...:  76% 91470/120000 [00:09<00:03, 9505.43 examples/s]
# Generating train examples...:  77% 92421/120000 [00:09<00:02, 9504.67 examples/s]
# Generating train examples...:  78% 93378/120000 [00:09<00:02, 9521.78 examples/s]
# Generating train examples...:  79% 94331/120000 [00:09<00:02, 9210.06 examples/s]
# Generating train examples...:  79% 95293/120000 [00:10<00:02, 9328.51 examples/s]
# Generating train examples...:  80% 96253/120000 [00:10<00:02, 9408.35 examples/s]
# Generating train examples...:  81% 97202/120000 [00:10<00:02, 9429.96 examples/s]
# Generating train examples...:  82% 98153/120000 [00:10<00:02, 9453.23 examples/s]
# Generating train examples...:  83% 99113/120000 [00:10<00:02, 9496.42 examples/s]
# Generating train examples...:  83% 100067/120000 [00:10<00:02, 9507.17 examples/s]
# Generating train examples...:  84% 101028/120000 [00:10<00:01, 9537.65 examples/s]
# Generating train examples...:  85% 101986/120000 [00:10<00:01, 9547.52 examples/s]
# Generating train examples...:  86% 102941/120000 [00:10<00:01, 9466.41 examples/s]
# Generating train examples...:  87% 103888/120000 [00:10<00:01, 9446.77 examples/s]
# Generating train examples...:  87% 104848/120000 [00:11<00:01, 9490.18 examples/s]
# Generating train examples...:  88% 105804/120000 [00:11<00:01, 9510.77 examples/s]
# Generating train examples...:  89% 106756/120000 [00:11<00:01, 9445.25 examples/s]
# Generating train examples...:  90% 107709/120000 [00:11<00:01, 9468.62 examples/s]
# Generating train examples...:  91% 108658/120000 [00:11<00:01, 9473.21 examples/s]
# Generating train examples...:  91% 109606/120000 [00:11<00:01, 9465.12 examples/s]
# Generating train examples...:  92% 110572/120000 [00:11<00:00, 9521.04 examples/s]
# Generating train examples...:  93% 111525/120000 [00:11<00:00, 9489.29 examples/s]
# Generating train examples...:  94% 112474/120000 [00:11<00:00, 9489.38 examples/s]
# Generating train examples...:  95% 113423/120000 [00:11<00:00, 9195.59 examples/s]
# Generating train examples...:  95% 114384/120000 [00:12<00:00, 9316.53 examples/s]
# Generating train examples...:  96% 115348/120000 [00:12<00:00, 9411.43 examples/s]
# Generating train examples...:  97% 116313/120000 [00:12<00:00, 9480.93 examples/s]
# Generating train examples...:  98% 117276/120000 [00:12<00:00, 9523.94 examples/s]
# Generating train examples...:  99% 118233/120000 [00:12<00:00, 9535.60 examples/s]
# Generating train examples...:  99% 119188/120000 [00:12<00:00, 9539.11 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-train.tfrecord*...:   0% 0/120000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-train.tfrecord*...:   2% 2715/120000 [00:00<00:04, 27148.60 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-train.tfrecord*...:  43% 51926/120000 [00:00<00:00, 300639.14 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-train.tfrecord*...:  84% 101183/120000 [00:00<00:00, 388267.86 examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-train.tfrecord*. Number of examples: 120000 (shards: [120000])
# Generating splits...:  50% 1/2 [00:13<00:13, 13.04s/ splits]
# Generating test examples...:   0% 0/7600 [00:00<?, ? examples/s]
# Generating test examples...:  13% 966/7600 [00:00<00:00, 9658.35 examples/s]
# Generating test examples...:  25% 1935/7600 [00:00<00:00, 9672.37 examples/s]
# Generating test examples...:  38% 2903/7600 [00:00<00:00, 9661.83 examples/s]
# Generating test examples...:  51% 3870/7600 [00:00<00:00, 9623.65 examples/s]
# Generating test examples...:  64% 4835/7600 [00:00<00:00, 9630.92 examples/s]
# Generating test examples...:  76% 5799/7600 [00:00<00:00, 9609.34 examples/s]
# Generating test examples...:  89% 6770/7600 [00:00<00:00, 9639.89 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-test.tfrecord*...:   0% 0/7600 [00:00<?, ? examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete942P37/ag_news_subset-test.tfrecord*. Number of examples: 7600 (shards: [7600])
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.
# INFO[build.py]: Dataset generation complete...
#
# tfds.core.DatasetInfo(
#     name='ag_news_subset',
#     full_name='ag_news_subset/1.0.0',
#     description="""
#     AG is a collection of more than 1 million news articles.
#     News articles have been gathered from more than 2000  news sources by ComeToMyHead in more than 1 year of activity.
#     ComeToMyHead is an academic news search engine which has been running since July, 2004.
#     The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc),
#     information retrieval (ranking, search, etc), xml, data compression, data streaming,
#     and any other non-commercial activity.
#     For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html .
#
#     The AG's news topic classification dataset is constructed by Xiang Zhang (xiang.zhang@nyu.edu) from the dataset above.
#     It is used as a text classification benchmark in the following paper:
#     Xiang Zhang, Junbo Zhao, Yann LeCun. Character-level Convolutional Networks for Text Classification. Advances in Neural Information Processing Systems 28 (NIPS 2015).
#
#     The AG's news topic classification dataset is constructed by choosing 4 largest classes from the original corpus.
#     Each class contains 30,000 training samples and 1,900 testing samples.
#     The total number of training samples is 120,000 and testing 7,600.
#     """,
#     homepage='https://arxiv.org/abs/1509.01626',
#     data_path='/root/tensorflow_datasets/ag_news_subset/1.0.0',
#     file_format=tfrecord,
#     download_size=11.24 MiB,
#     dataset_size=35.79 MiB,
#     features=FeaturesDict({
#         'description': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
#         'title': Text(shape=(), dtype=tf.string),
#     }),
#     supervised_keys=('description', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=7600, num_shards=1>,
#         'train': <SplitInfo num_examples=120000, num_shards=1>,
#     },
#     citation="""@misc{zhang2015characterlevel,
#         title={Character-level Convolutional Networks for Text Classification},
#         author={Xiang Zhang and Junbo Zhao and Yann LeCun},
#         year={2015},
#         eprint={1509.01626},
#         archivePrefix={arXiv},
#         primaryClass={cs.LG}
#     }""",
# )

# %% [markdown]
# ## Preparing Integer Sequence Datasets

# %%
nltk.download('stopwords')
STOPWORDS = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
max_length = 150
max_tokens = 1000
text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,
    standardize=custom_stopwords
)
text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_test_ds = test_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %% [markdown]
# ## Experiment C1: Bi-directional LSTM One-Hot Encoded Vector Sequences
#
# 1 bio-directional layer (32)
#
# Dropout 0.5
#
# Output activation: softmax

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = tf.one_hot(inputs, depth=max_tokens)
x = layers.Bidirectional(layers.LSTM(32))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model1 = tf.keras.Model(inputs, outputs)
model1.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  tf.one_hot (TFOpLambda)     (None, None, 1000)        0
#
#  bidirectional (Bidirectiona  (None, 64)               264448
#  l)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 4)                 260
#
# =================================================================
# Total params: 264,708
# Trainable params: 264,708
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model1, "BiDirectionalSimpleRNN.png", show_shapes=True)

# %%
## Train model
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("one_hot_bidir_lstm.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
history1 = model1.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model1 = keras.models.load_model("one_hot_bidir_lstm.keras")
print(f"Test acc: {model1.evaluate(int_test_ds)[1]:.3f}")
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 63s 15ms/step - loss: 0.5816 - accuracy: 0.7942 - val_loss: 0.4159 - val_accuracy: 0.8562
# Epoch 2/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4369 - accuracy: 0.8516 - val_loss: 0.4049 - val_accuracy: 0.8583
# Epoch 3/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4234 - accuracy: 0.8552 - val_loss: 0.3994 - val_accuracy: 0.8597
# Epoch 4/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4153 - accuracy: 0.8589 - val_loss: 0.3964 - val_accuracy: 0.8612
# Epoch 5/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4082 - accuracy: 0.8603 - val_loss: 0.3980 - val_accuracy: 0.8578
# Epoch 6/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.4010 - accuracy: 0.8619 - val_loss: 0.3950 - val_accuracy: 0.8610
# Epoch 7/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.3974 - accuracy: 0.8642 - val_loss: 0.3920 - val_accuracy: 0.8635
# Epoch 8/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.3936 - accuracy: 0.8657 - val_loss: 0.3958 - val_accuracy: 0.8622
# Epoch 9/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.3898 - accuracy: 0.8660 - val_loss: 0.3933 - val_accuracy: 0.8618
# Epoch 10/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3841 - accuracy: 0.8685 - val_loss: 0.3954 - val_accuracy: 0.8620
# 238/238 [==============================] - 3s 8ms/step - loss: 0.3975 - accuracy: 0.8620
# Test acc: 0.862

# %%
## Metrics
history_dict = history1.history
history_dict.keys()

losses = history1.history['loss']
accs = history1.history['accuracy']
val_losses = history1.history['val_loss']
val_accs = history1.history['val_accuracy']
epochs = len(losses)

# %%
## Loss and Accuracy
plt.figure(figsize=(15, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Experiment C2: Bi-directional LSTM One-Hot Encoded Vector Sequences
#
# 1 bio-directional layer (32)
#
# Dropout 0.5
#
# Output activation: Sigmoid

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = tf.one_hot(inputs, depth=max_tokens)
x = layers.Bidirectional(layers.LSTM(32))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="sigmoid")(x)
model2 = tf.keras.Model(inputs, outputs)
model2.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, None)]            0
#
#  tf.one_hot_1 (TFOpLambda)   (None, None, 1000)        0
#
#  bidirectional_1 (Bidirectio  (None, 64)               264448
#  nal)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 264,708
# Trainable params: 264,708
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model2, "BiDirectionalSimpleRNN2.png", show_shapes=True)

# %%
## Train model
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("one_hot_bidir_lstm.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
history2 = model2.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model2 = keras.models.load_model("one_hot_bidir_lstm.keras")
print(f"Test acc: {model2.evaluate(int_test_ds)[1]:.3f}")
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 58s 15ms/step - loss: 0.5747 - accuracy: 0.7978 - val_loss: 0.4166 - val_accuracy: 0.8548
# Epoch 2/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4377 - accuracy: 0.8507 - val_loss: 0.3981 - val_accuracy: 0.8595
# Epoch 3/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4220 - accuracy: 0.8549 - val_loss: 0.3989 - val_accuracy: 0.8585
# Epoch 4/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4121 - accuracy: 0.8586 - val_loss: 0.3940 - val_accuracy: 0.8593
# Epoch 5/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4054 - accuracy: 0.8609 - val_loss: 0.3931 - val_accuracy: 0.8622
# Epoch 6/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.4010 - accuracy: 0.8618 - val_loss: 0.3931 - val_accuracy: 0.8617
# Epoch 7/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3959 - accuracy: 0.8648 - val_loss: 0.3971 - val_accuracy: 0.8602
# Epoch 8/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3938 - accuracy: 0.8652 - val_loss: 0.3977 - val_accuracy: 0.8623
# Epoch 9/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3888 - accuracy: 0.8667 - val_loss: 0.3924 - val_accuracy: 0.8612
# Epoch 10/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3840 - accuracy: 0.8683 - val_loss: 0.4050 - val_accuracy: 0.8590
# Epoch 11/200
# 3563/3563 [==============================] - 54s 15ms/step - loss: 0.3813 - accuracy: 0.8707 - val_loss: 0.3985 - val_accuracy: 0.8618
# 238/238 [==============================] - 3s 8ms/step - loss: 0.4005 - accuracy: 0.8600
# Test acc: 0.860

# %%
## Metrics
history_dict = history2.history
history_dict.keys()

losses = history2.history['loss']
accs = history2.history['accuracy']
val_losses = history2.history['val_loss']
val_accs = history2.history['val_accuracy']
epochs = len(losses)

# %%
## Loss and Accuracy
plt.figure(figsize=(15, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Experiment C3: Unidirectional RNN One-Hot Encoded Vector Sequences
#
# 1 bio-directional layer (32)
#
# Dropout 0.5
#
# Output activation: Softmax

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = tf.one_hot(inputs, depth=max_tokens)
x = layers.LSTM(32)(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model3 = tf.keras.Model(inputs, outputs)
model3.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, None)]            0
#
#  tf.one_hot_2 (TFOpLambda)   (None, None, 1000)        0
#
#  lstm_2 (LSTM)               (None, 32)                132224
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 132,356
# Trainable params: 132,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model3, "UnidirectionalSimpleRNN3.png", show_shapes=True)

# %%
## Train model
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("one_hot_bidir_lstm.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
history3 = model3.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model3 = keras.models.load_model("one_hot_bidir_lstm.keras")
print(f"Test acc: {model1.evaluate(int_test_ds)[1]:.3f}")
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 34s 9ms/step - loss: 1.3870 - accuracy: 0.2516 - val_loss: 1.3867 - val_accuracy: 0.2515
# Epoch 2/200
# 3563/3563 [==============================] - 32s 9ms/step - loss: 1.3866 - accuracy: 0.2525 - val_loss: 1.3867 - val_accuracy: 0.2515
# Epoch 3/200
# 3563/3563 [==============================] - 31s 9ms/step - loss: 1.3866 - accuracy: 0.2506 - val_loss: 1.3866 - val_accuracy: 0.2515
# Epoch 4/200
# 3563/3563 [==============================] - 31s 9ms/step - loss: 1.3865 - accuracy: 0.2516 - val_loss: 1.3865 - val_accuracy: 0.2515
# 238/238 [==============================] - 2s 8ms/step - loss: 0.3975 - accuracy: 0.8620
# Test acc: 0.862

# %%
## Metrics
history_dict = history3.history
history_dict.keys()

losses = history3.history['loss']
accs = history3.history['accuracy']
val_losses = history3.history['val_loss']
val_accs = history3.history['val_accuracy']
epochs = len(losses)

# %%
## Loss and Accuracy
plt.figure(figsize=(15, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Experiment C4: Bi-directional RNN One-Hot Encoded Vector Sequences
#
# 1 bio-directional layers (64)
#
# Dropout 0.5
#
# Output activation: softmax

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = tf.one_hot(inputs, depth=max_tokens)
x = layers.Bidirectional(layers.LSTM(64))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model4 = tf.keras.Model(inputs, outputs)
model4.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model4.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, None)]            0
#
#  tf.one_hot_3 (TFOpLambda)   (None, None, 1000)        0
#
#  bidirectional_2 (Bidirectio  (None, 128)              545280
#  nal)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 545,796
# Trainable params: 545,796
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model4, "BiDirectionalSimpleRNN2.png", show_shapes=True)

# %%
## Train model
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("one_hot_bidir_lstm.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
history4 = model4.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model4 = keras.models.load_model("one_hot_bidir_lstm.keras")
print(f"Test acc: {model4.evaluate(int_test_ds)[1]:.3f}")
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 59s 16ms/step - loss: 0.5313 - accuracy: 0.8123 - val_loss: 0.4184 - val_accuracy: 0.8538
# Epoch 2/200
# 3563/3563 [==============================] - 55s 16ms/step - loss: 0.4228 - accuracy: 0.8535 - val_loss: 0.4107 - val_accuracy: 0.8543
# Epoch 3/200
# 3563/3563 [==============================] - 55s 16ms/step - loss: 0.4079 - accuracy: 0.8580 - val_loss: 0.3996 - val_accuracy: 0.8593
# Epoch 4/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3986 - accuracy: 0.8609 - val_loss: 0.3951 - val_accuracy: 0.8577
# Epoch 5/200
# 3563/3563 [==============================] - 55s 16ms/step - loss: 0.3903 - accuracy: 0.8646 - val_loss: 0.3966 - val_accuracy: 0.8572
# Epoch 6/200
# 3563/3563 [==============================] - 55s 16ms/step - loss: 0.3843 - accuracy: 0.8654 - val_loss: 0.3928 - val_accuracy: 0.8603
# Epoch 7/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3783 - accuracy: 0.8687 - val_loss: 0.3957 - val_accuracy: 0.8595
# Epoch 8/200
# 3563/3563 [==============================] - 56s 16ms/step - loss: 0.3722 - accuracy: 0.8713 - val_loss: 0.3911 - val_accuracy: 0.8635
# Epoch 9/200
# 3563/3563 [==============================] - 55s 16ms/step - loss: 0.3657 - accuracy: 0.8732 - val_loss: 0.3931 - val_accuracy: 0.8640
# Epoch 10/200
# 3563/3563 [==============================] - 55s 16ms/step - loss: 0.3593 - accuracy: 0.8757 - val_loss: 0.3992 - val_accuracy: 0.8605
# Epoch 11/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3541 - accuracy: 0.8787 - val_loss: 0.3933 - val_accuracy: 0.8645
# Epoch 12/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3490 - accuracy: 0.8799 - val_loss: 0.4014 - val_accuracy: 0.8610
# Epoch 13/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3431 - accuracy: 0.8818 - val_loss: 0.4030 - val_accuracy: 0.8620
# Epoch 14/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.3372 - accuracy: 0.8843 - val_loss: 0.4085 - val_accuracy: 0.8635
# 238/238 [==============================] - 3s 8ms/step - loss: 0.3933 - accuracy: 0.8647
# Test acc: 0.865

# %%
## Metrics
history_dict = history2.history
history_dict.keys()

losses = history4.history['loss']
accs = history4.history['accuracy']
val_losses = history4.history['val_loss']
val_accs = history4.history['val_accuracy']
epochs = len(losses)

# %%
## Loss and Accuracy
plt.figure(figsize=(15, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Model Leveraging Trained Embedding Layer

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = layers.Embedding(input_dim=max_tokens, output_dim=256)(inputs)
x = layers.Bidirectional(layers.SimpleRNN(32))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model = tf.keras.Model(inputs, outputs)
model.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model.summary()

# %%
## Train model
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("embeddings_bidir_gru.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
model.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model = keras.models.load_model("embeddings_bidir_gru.keras")
print(f"Test acc: {model.evaluate(int_test_ds)[1]:.3f}")

# %%
keras.utils.plot_model(model2, "BiDirectionalSimpleRNN2.png", show_shapes=True)

# %%
## Metrics
history_dict = history2.history
history_dict.keys()

losses = history2.history['loss']
accs = history2.history['accuracy']
val_losses = history2.history['val_loss']
val_accs = history2.history['val_accuracy']
epochs = len(losses)

# %%
## Loss and Accuracy
plt.figure(figsize=(15, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Model Leveraging Embedding Layer With Masking Enabled

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = layers.Embedding(
    input_dim=max_tokens, output_dim=256, mask_zero=True)(inputs)
x = layers.Bidirectional(layers.LSTM(32))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model = tf.keras.Model(inputs, outputs)
model.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model.summary()

callbacks = [
    tf.keras.callbacks.ModelCheckpoint("embeddings_bidir_gru_with_masking.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
model.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model = keras.models.load_model("embeddings_bidir_gru_with_masking.keras")
print(f"Test acc: {model.evaluate(int_test_ds)[1]:.3f}")

# %% [markdown]
# ## Using Pretrained Word Embeddings

# %% [markdown]
# The rationale behind using `pretrained word embedding`s in natural language processing is much the same as for using pretrained convnets in image classification: *you don’t have enough data available to learn truly powerful features on your own*, but you expect that the features you need are fairly generic—that is, common visual features or semantic features. In this case, it makes sense to reuse features learned on a different problem.

# %% [markdown]
# The idea of a dense, low-dimensional embedding space for words, computed in an unsupervised way, was initially explored by Bengio et al. in the early 2000s, but it only started to take off in research and industry applications after the release of one of the most famous and successful word-embedding schemes: the `Word2Vec` algorithm (https://code.google.com/archive/p/word2vec), developed by Tomas Mikolov at Google in 2013. `Word2Vec` dimensions capture specific semantic properties, such as gender.

# %% [markdown]
# There are various precomputed databases of word embeddings that you can download and use in a Keras Embedding layer. `Word2vec` is one of them. Another popular one is called `Global Vectors for Word Representatio`n (GloVe, https://nlp.stanford.edu/projects/glove), which was developed by Stanford researchers in 2014. This embedding technique is based on factorizing a matrix of word co-occurrence statistics. Its developers have made available precomputed embeddings for millions of English tokens, obtained from Wikipedia data and Common Crawl data.

# %% [markdown]
# First, let’s download the GloVe word embeddings precomputed on the 2014 English Wikipedia dataset. It’s an 822 MB zip file containing 100-dimensional embedding vectors for 400,000 words (or non-word tokens).

# %% [markdown]
# <div class="alert alert-block alert-success"><b>GloVe: Global Vectors for Word Representation</b><br>
# https://nlp.stanford.edu/projects/glove/</div>

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip -q glove.6B.zip

# %% [markdown]
# ## Parsing The GloVe Word-Embeddings File
#
# First line of `glove.6B.100d.txt`:
#
# `the -0.038194 -0.24487 0.72812 ...`

# %%
path_to_glove_file = "glove.6B.100d.txt"

embeddings_index = {}
with open(path_to_glove_file) as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ") # np.dtype('f') returns dtype('float32')
        embeddings_index[word] = coefs

print(f"Found {len(embeddings_index)} word vectors.")

# %% [markdown]
# ## Preparing The GloVe Word-Embeddings Matrix
#
# Next, let’s build an embedding matrix that you can load into an Embedding layer. It must be a matrix of shape `(max_words, embedding_dim)`, where each entry *i* contains the `embedding_dim`-dimensional vector for the word of index *i* in the reference word index (built during tokenization).

# %%
embedding_dim = 100

# Retrieve the vocabulary indexed by our previous TextVectorization layer.
vocabulary = text_vectorization.get_vocabulary()

# Use it to create a mapping from words to their index in the vocabulary.
word_index = dict(zip(vocabulary, range(len(vocabulary))))

# Prepare a matrix that we’ll fill with the GloVe vectors.
embedding_matrix = np.zeros((max_tokens, embedding_dim))

# Fill entry i in the matrix with the word vector for index i.
for word, i in word_index.items():
    if i < max_tokens:
        embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:  # Words not found in the embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = layers.Embedding(
    max_tokens,
    embedding_dim,
    embeddings_initializer=keras.initializers.Constant(embedding_matrix),
    trainable=False,
    mask_zero=True,
)

# %% [markdown]
# We’re now ready to train a new model—identical to our previous model, but leveraging the `100-dimensional` pretrained GloVe embeddings instead of `256-dimensional` learned embeddings.

# %% [markdown]
# ## One possible alternative to GloVE: ELMo (Embedding from Language Models)

# %% [markdown]
# ## Model Leveraging Pretrained (GloVe) Embedding Layer

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = embedding_layer(inputs)
x = layers.Bidirectional(layers.LSTM(32))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model = tf.keras.Model(inputs, outputs)
model.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model.summary()

callbacks = [
    tf.keras.callbacks.ModelCheckpoint("glove_embeddings_sequence_model.keras",
                                    save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
model.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model = keras.models.load_model("glove_embeddings_sequence_model.keras")
print(f"Test acc: {model.evaluate(int_test_ds)[1]:.3f}")
